# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# 결과 확인을 용이하게 하기 위한 코드
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # sns 기본

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.hist(np.random.standard_normal(100), bins = 20, color = 'red', alpha = 0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.standard_normal(30))
ax3.plot(np.random.standard_normal(50).cumsum(), color = 'red', linestyle = 'dashed')

# %%
fig, axes = plt.subplots(2, 3)
axes
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex = True, sharey = True) # x축과 y축을 공유한다

for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.standard_normal(500), bins = 50, color = 'black', alpha = 0.5)

fig.subplots_adjust(wspace = 0, hspace = 0) # 그래프간 간격

# %%
ax = fig.add_subplot()

ax.plot(np.random.standard_normal(30).cumsum(), color = 'black', linestyle = 'dashed', marker = 'o')

# %%
fig = plt.figure()

ax = fig.add_subplot()

data = np.random.standard_normal(30).cumsum()

ax.plot(data, color = 'black', linestyle = 'dashed', label = 'Default')
ax.plot(data, color = 'black', drawstyle = 'steps-post', label = 'steps-post')
ax.legend()

# %%
fig, ax = plt.subplots()

data = np.random.standard_normal(30).cumsum()

ax.plot(data, color = 'green')

# %%
fig, ax = plt.subplots()

ax.plot(np.random.standard_normal(1000).cumsum())

ax.set_xticks([0, 250, 500, 750, 1000])
ax.set_xticklabels(['one', 'two', 'three', 'foer', 'five'], rotation = 30, fontsize = 10)
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 0, 'Stages')

# %%
fig, ax = plt.subplots()

ax.plot(np.random.randn(1000).cumsum(), color = 'black', label = 'one')
ax.plot(np.random.randn(1000).cumsum(), color = 'red', label = 'two', linestyle = 'dashed')
ax.plot(np.random.randn(1000).cumsum(), color = 'green', label = 'three', linestyle = 'dotted')
ax.legend(loc = 'upper left')

# %%
from datetime import datetime

fig, ax = plt.subplot

data = pd.read_csv('spx.csv', index_col = 0, parse_dates = True)
spx = data['SPX']

spx.plot(ax = ax, color = 'black')

crisis_data = [
    (datetime(2007, 10, 11), "Peak of bull market"),
    (datetime(2008, 3, 12), "Bear Stearns Fails"),
    (datetime(2008, 9, 15), "Lehman Bankruptcy")
]

for date, label in crisis_data:
    ax.annotate(label, xy = (date, spx.asof(date) + 75),
               xytext = (date, spx.asof(date) + 225),
               arrowprops=dict(facecolor = 'black', headwidth = 4, width = 2, headlength = 4),
               horizontalalignment = 'left', verticalalignment = 'top')
    
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008 - 2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008 - 2009 financial crisis')

# %%
fig, ax = plt.subplots()

rect = plt.Rectangle((0.2, 0.65), 0.5, 0.2, color = 'blue', alpha = 0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color = 'pink', alpha = 0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color = 'green', alpha = 0.3)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

fig.savefig('figpath.png', dpi = 60) #그래프를 파일로 저장하기

# %%
s = pd.Series(np.random.standard_normal(10).cumsum(), index = np.arange(0, 100, 10))
s.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.standard_normal((10, 4)).cumsum(0),
                 columns = ['A', 'B', 'C', 'D'],
                 index = np.arange(0, 100, 10))
plt.style.use('grayscale')

df.plot()
# Out:
# <Axes: >

# %%
fig, axes = plt.subplots(2, 1)
_= plt.figure(figsize = (15, 6))
data = pd.Series(np.random.uniform(size = 16), index = list('abcdefghijklmnop'))
data.plot.bar(ax = axes[0], color = 'black', alpha = 0.7,  grid = True)
data.plot.barh(ax = axes[1], color = 'black', alpha = 0.7, grid = True)
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.uniform(size = (6, 4)), index = ['one', 'two', 'three', 'four', 'five', 'six'],
                 columns = pd.Index(['A', 'B', 'C', 'D'], name = 'Genus'))
df.plot.bar()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.uniform(size = (6, 4)), index = ['one', 'two', 'three', 'four', 'five', 'six'],
                 columns = pd.Index(['A', 'B', 'C', 'D'], name = 'Genus'))
df.plot.barh(stacked = True, alpha = 0.8)
# Out:
# <Axes: >

# %%
tips = pd.read_csv('tips.csv')

tips.head()

party_counts = pd.crosstab(tips['day'], tips['size'])
party_counts = party_counts.reindex(index = ['Thur', 'Fri', 'Sat', 'Sun'])
party_counts = party_counts.loc[:, 2:5]

party_pcts = party_counts.div(party_counts.sum(axis = 'columns'), axis = 'index')
party_pcts
party_pcts.plot.bar(stacked = True)
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4
# size         2         3         4         5
# day
# Thur  0.827586  0.068966  0.086207  0.017241
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# <Axes: xlabel='day'>

# %%
import seaborn as sns 
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])

tips.head()
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069
# <Axes: xlabel='tip_pct', ylabel='day'>

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])

tips.head()

sns.barplot(x='tip_pct', y='day', hue = 'time', data=tips, orient='h')
sns.set_style('whitegrid')
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pct
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.172069
# <Axes: xlabel='tip_pct', ylabel='day'>

# %%
tips['tip_pct'].plot.hist(bins = 50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
tips['tip_pct'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
c1 = np.random.standard_normal(200)
c2 = 10 + 2 * np.random.standard_normal(200)

val = pd.Series(np.concatenate([c1, c2]))
val.head()

sns.histplot(val, bins = 100, color = 'black')
# Out:
# 0    0.371792
# 1    1.941719
# 2    0.147644
# 3    0.108036
# 4   -0.434221
# dtype: float64
# <Axes: ylabel='Count'>

# %%
macro = pd.read_csv('macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()
trans_data.head()


ax = sns.regplot(x = 'm1', y = 'unemp', data = trans_data)
ax.set_title('changes in log(m1) versus log(unemp)')
# Out:
#         cpi        m1  tbilrate     unemp
# 1  0.005849  0.014215  0.088193 -0.128617
# 2  0.006838 -0.008505  0.215321  0.038466
# 3  0.000681 -0.003565  0.125317  0.055060
# 4  0.005772 -0.002861 -0.212805 -0.074108
# 5  0.000338  0.004289 -0.266946  0.000000
# Text(0.5, 1.0, 'changes in log(m1) versus log(unemp)')

# %%
sns.pairplot(trans_data, diag_kind = 'kde', plot_kws = {'alpha' : 0.2})

# %%
sns.catplot(x = 'day', y = 'tip_pct', hue = 'time', col = 'smoker', kind = 'bar', 
           data = tips[tips['tip_pct'] < 1])

# %%
sns.catplot(x = 'day', y = 'tip_pct', row = 'time', col = 'smoker', kind = 'bar', 
           data = tips[tips['tip_pct'] < 1])

# %%
sns.catplot(x = 'tip_pct', y = 'day', kind = 'box', 
           data = tips[tips['tip_pct'] < 0.5])

# %% [markdown]
# # sns 특강

# %%
import seaborn as sns
import pandas as pd

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['sex'].unique() # 성별에 뭐 있는지
df['sex'].nunique() # 성별을 몇 개로 나누는지
df['sex'].value_counts() # 성별에 뭐가 있고 그 것은 몇 개인지
df.groupby('sex').size()# 성별에 뭐가 있고 그 것은 몇 개인지
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']
# 2
# sex
# Male      157
# Female     87
# Name: count, dtype: int64
# sex
# Male      157
# Female     87
# dtype: int64

# %%
df['day'].value_counts()

df['time'].value_counts().sort_values(ascending = True)
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64
# time
# Lunch      68
# Dinner    176
# Name: count, dtype: int64

# %%
# 음식 가격과 팁의 상관관계
sns.scatterplot(x = df['total_bill'], y = df['tip'], s = 50, marker = '+')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = df['total_bill'], y = df['tip'], hue = df['sex'], size = df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = df['total_bill'], y = df['tip'], hue = df['day'], style = df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = df['total_bill'], y = df['tip'], hue = df['sex'], size = df['day'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
fig, axes = plt.subplots(1, 3, figsize = (9, 3))

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]
sns.scatterplot(x = x, y = y, ax = axes[0])
sns.barplot(x = x, y = y, ax = axes[1])
sns.lineplot(x = x, y = y, ax = axes[2])
# Out:
# <Axes: >
# <Axes: >
# <Axes: >

# %%
fig, axes = plt.subplots(1, 2, figsize = (18,  5))

sns.regplot(x = df['total_bill'], y = df['tip'], ax = axes[0])
sns.regplot(x = df['total_bill'], y = df['tip'], scatter = False, ax = axes[1])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = df['total_bill'], y = df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = df['size'], y = df['tip'])
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
fig, axes = plt.subplots(1, 2, figsize = (16, 8))

sns.barplot(x = df['size'], y = df['tip'], ax = axes[0])
sns.barplot(x = df['size'], y = df['tip'], ci = None, ax = axes[1])
# Out:
# <Axes: xlabel='size', ylabel='tip'>
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.countplot(x = df['day'])
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.pointplot(x = df['day'], y = df['tip']) # 점은 평균값, 위아래 직선은 신뢰구간
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x = df['size'], y = df['tip'])
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.violinplot(x = df['size'], y = df['tip'], hue = df['sex'])
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.histplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df['total_bill'], bins = 100)
# sns.histplot(df['total_bill'], bins = 3)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = df['total_bill'], kde = True, bins = 100)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data = df['day'])
# sns.histplot(data = df['day'], kde = True)
# Out:
# <Axes: xlabel='day', ylabel='Count'>

# %%
sns.kdeplot(data = df['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.rugplot(x = df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
# gb_df = df.pivot_table('tip', 'day', 'size')

gb_df = df.groupby(['day', 'size'])['tip'].mean().reset_index()
gb_df = gb_df.pivot(index = 'day', columns = 'size', values = 'tip')
gb_df
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000       NaN  NaN
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  NaN
# Sun    NaN  2.816923  3.120667  4.087778  4.046667  5.0

# %%
# gb_df = df.pivot_table('tip', 'day', 'size', aggfunc = 'count')

gb_df = df.groupby(['day', 'size'])['tip'].size().reset_index()
gb_df = gb_df.pivot(index = 'day', columns = 'size', values = 'tip')
gb_df
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
gb_df = df.pivot_table('tip', 'day', 'size')

sns.heatmap(gb_df)
# Out:
# <Axes: xlabel='size', ylabel='day'>

# %%
gb_df = df.pivot_table('tip', 'day', 'size')
gb_df = gb_df.fillna(0)
gb_df

sns.heatmap(gb_df)
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000  0.000000  0.0
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  0.0
# Sun   0.00  2.816923  3.120667  4.087778  4.046667  5.0
# <Axes: xlabel='size', ylabel='day'>

# %%
gb_df = df.pivot_table('tip', 'day', 'size')
gb_df = gb_df.fillna(0)
gb_df

sns.heatmap(gb_df, annot = True)
# Out:
# size     1         2         3         4         5    6
# day
# Thur  1.83  2.442500  2.692500  4.218000  5.000000  5.3
# Fri   1.92  2.644375  3.000000  4.730000  0.000000  0.0
# Sat   1.00  2.517547  3.797778  4.123846  3.000000  0.0
# Sun   0.00  2.816923  3.120667  4.087778  4.046667  5.0
# <Axes: xlabel='size', ylabel='day'>

# %% [markdown]
# # 특강 2

# %%
x = ['cat', 'dog', 'fish', 'bjird', 'snake', 'bee']
y = [98, 84, 45, 55, 68, 72]

plt.bar(x, y)
# Out:
# <BarContainer object of 6 artists>

# %%
x = range(6)
y = range(10, 70, 10)

plt.bar(x, y, width = 1, align = 'edge', color = 'red', edgecolor = 'yellow', linewidth = 2)
# Out:
# <BarContainer object of 6 artists>

# %%
x = range(6)
y = range(10, 70, 10)

plt.bar(x, y, width = 1, align = 'edge', color = 'red', edgecolor = 'yellow', linewidth = 2)
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend(['sales'])
plt.grid(True, axis = 'y')
# Out:
# <BarContainer object of 6 artists>
# Text(0.5, 1.0, 'Monthly Sales')
# Text(0.5, 0, 'Month')
# Text(0, 0.5, 'Sales')

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows = 2, ncols = 3)
fig.set_size_inches(16, 8)

ax1.set(title = '1st plot')
ax2.set(title = '2st plot')
ax3.set(title = '3st plot')
ax4.set(title = '4st plot')
ax5.set(title = '5st plot', xlabel='month', ylabel='sales')
ax6.set(title = '6st plot')

x = range(6)
y = range(10, 70, 10)

ax5.bar(x, y, width = 1, align = 'edge', color = 'red', edgecolor = 'yellow', linewidth = 2)
ax5.grid(True, axis= 'y')
# Out:
# [Text(0.5, 1.0, '1st plot')]
# [Text(0.5, 1.0, '2st plot')]
# [Text(0.5, 1.0, '3st plot')]
# [Text(0.5, 1.0, '4st plot')]
# [Text(0.5, 1.0, '5st plot'), Text(0.5, 0, 'month'), Text(0, 0.5, 'sales')]
# [Text(0.5, 1.0, '6st plot')]
# <BarContainer object of 6 artists>

# %%
x = range(1, 13)
y = range(10, 130, 10)

fig = plt.figure(figsize=(6.4, 4.8))
plt.bar(x, y)
plt.title('월별 매출')
plt.xlabel('월')
plt.ylabel('매출')
# Out:
# <BarContainer object of 12 artists>
# Text(0.5, 1.0, '월별 매출')
# Text(0.5, 0, '월')
# Text(0, 0.5, '매출')

# %%
from matplotlib import font_manager, rc
font_path = "C:/Users/mit005/Desktop/project/font/나눔 글꼴/나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothic.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
x = range(1, 13)
y = range(10, 130, 10)

fig = plt.figure(figsize=(6.4, 4.8))
plt.bar(x, y)

plt.rcParams['font.family'] = 'Nanum Gothic'

plt.title('월별 매출')
plt.xlabel('월')
plt.ylabel('매출')
# Out:
# <BarContainer object of 12 artists>
# Text(0.5, 1.0, '월별 매출')
# Text(0.5, 0, '월')
# Text(0, 0.5, '매출')
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# findfont: Font family '나눔 고딕' not found.
# ...
